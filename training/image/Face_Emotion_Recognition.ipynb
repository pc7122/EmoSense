# %%
from google.colab import drive
drive.mount('mydrive')
# Out:
# Mounted at mydrive

# %%
from zipfile import ZipFile
file_name = "/content/mydrive/MyDrive/My Files/Datasets/Facial Emotion/archive.zip"

with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print("Done")
# Out:
# Done

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from keras.preprocessing.image import ImageDataGenerator

# %%
os.listdir("train/")
# Out:
# ['fear', 'angry', 'sad', 'surprise', 'neutral', 'disgust', 'happy']

# %%
train_dir = "train/"
val_dir = "test/"
num_classes = 7

BATCH_SIZE = 32
IMG_SIZE = 48

# %%
datagen = ImageDataGenerator(
    rotation_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    rescale=1./255,
)

# %%
train_gen = datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True,
    class_mode="sparse",
)

test_gen = datagen.flow_from_directory(
    val_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True,
    class_mode="sparse",
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
len(train_gen)
# Out:
# 898

# %%
class_names = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
class_names
# Out:
# ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# %%
batch = train_gen.next()

plt.figure(figsize=(10, 5))
for i in range(18):
  plt.subplot(3, 6, i+1)
  plt.imshow(batch[0][i])
  plt.title(class_names[int(batch[1][i])])
  plt.axis("off")

# %%
def my_model():
  img_inputs = tf.keras.Input(shape=(48, 48, 3))

  # CNN Layers
  x = tf.keras.layers.Conv2D(64, 3, activation='relu', padding='same')(img_inputs)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv2D(64, 3, activation='relu', padding='same')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.MaxPooling2D(2)(x)
  x = tf.keras.layers.Dropout(0.3)(x)

  x = tf.keras.layers.Conv2D(128, 3, activation='relu', padding='same')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv2D(128, 3, activation='relu', padding='same')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv2D(128, 3, activation='relu', padding='same')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.MaxPooling2D(2)(x)
  x = tf.keras.layers.Dropout(0.3)(x)

  x = tf.keras.layers.Conv2D(256, 3, activation='relu', padding='same')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv2D(256, 3, activation='relu', padding='same')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv2D(256, 3, activation='relu', padding='same')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv2D(256, 3, activation='relu', padding='same')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.MaxPooling2D(2)(x)
  x = tf.keras.layers.Dropout(0.3)(x)

  x = tf.keras.layers.Conv2D(512, 3, activation='relu', padding='same')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv2D(512, 3, activation='relu', padding='same')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv2D(512, 3, activation='relu', padding='same')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv2D(512, 3, activation='relu', padding='same')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv2D(512, 3, activation='relu', padding='same')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.MaxPooling2D(2)(x)
  x = tf.keras.layers.Dropout(0.3)(x)

  # Dense Layers
  x = tf.keras.layers.Flatten()(x)

  x = tf.keras.layers.Dense(1024, activation="relu")(x)
  x = tf.keras.layers.Dropout(0.5)(x)

  output = tf.keras.layers.Dense(7, activation='softmax')(x)

  model = tf.keras.Model(inputs=img_inputs, outputs=output, name='Face_Emotion_Model')

  return model

# %%
model = my_model()
model.summary()
# Out:
# Model: "Face_Emotion_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 48, 48, 3)]       0
#
#  conv2d_13 (Conv2D)          (None, 48, 48, 64)        1792
#
#  batch_normalization_13 (Bat  (None, 48, 48, 64)       256
#  chNormalization)
#
#  conv2d_14 (Conv2D)          (None, 48, 48, 64)        36928
#
#  batch_normalization_14 (Bat  (None, 48, 48, 64)       256
#  chNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 24, 24, 64)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 24, 24, 64)        0
#
#  conv2d_15 (Conv2D)          (None, 24, 24, 128)       73856
#
#  batch_normalization_15 (Bat  (None, 24, 24, 128)      512
#  chNormalization)
#
#  conv2d_16 (Conv2D)          (None, 24, 24, 128)       147584
#
#  batch_normalization_16 (Bat  (None, 24, 24, 128)      512
#  chNormalization)
#
#  conv2d_17 (Conv2D)          (None, 24, 24, 128)       147584
#
#  batch_normalization_17 (Bat  (None, 24, 24, 128)      512
#  chNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 12, 12, 128)      0
#  2D)
#
#  dropout_6 (Dropout)         (None, 12, 12, 128)       0
#
#  conv2d_18 (Conv2D)          (None, 12, 12, 256)       295168
#
#  batch_normalization_18 (Bat  (None, 12, 12, 256)      1024
#  chNormalization)
#
#  conv2d_19 (Conv2D)          (None, 12, 12, 256)       590080
#
#  batch_normalization_19 (Bat  (None, 12, 12, 256)      1024
#  chNormalization)
#
#  conv2d_20 (Conv2D)          (None, 12, 12, 256)       590080
#
#  batch_normalization_20 (Bat  (None, 12, 12, 256)      1024
#  chNormalization)
#
#  conv2d_21 (Conv2D)          (None, 12, 12, 256)       590080
#
#  batch_normalization_21 (Bat  (None, 12, 12, 256)      1024
#  chNormalization)
#
#  max_pooling2d_6 (MaxPooling  (None, 6, 6, 256)        0
#  2D)
#
#  dropout_7 (Dropout)         (None, 6, 6, 256)         0
#
#  conv2d_22 (Conv2D)          (None, 6, 6, 512)         1180160
#
#  batch_normalization_22 (Bat  (None, 6, 6, 512)        2048
#  chNormalization)
#
#  conv2d_23 (Conv2D)          (None, 6, 6, 512)         2359808
#
#  batch_normalization_23 (Bat  (None, 6, 6, 512)        2048
#  chNormalization)
#
#  conv2d_24 (Conv2D)          (None, 6, 6, 512)         2359808
#
#  batch_normalization_24 (Bat  (None, 6, 6, 512)        2048
#  chNormalization)
#
#  conv2d_25 (Conv2D)          (None, 6, 6, 512)         2359808
#
#  batch_normalization_25 (Bat  (None, 6, 6, 512)        2048
#  chNormalization)
#
#  conv2d_26 (Conv2D)          (None, 6, 6, 512)         2359808
#
#  batch_normalization_26 (Bat  (None, 6, 6, 512)        2048
#  chNormalization)
#
#  max_pooling2d_7 (MaxPooling  (None, 3, 3, 512)        0
#  2D)
#
#  dropout_8 (Dropout)         (None, 3, 3, 512)         0
#
#  flatten_1 (Flatten)         (None, 4608)              0
#
#  dense_2 (Dense)             (None, 1024)              4719616
#
#  dropout_9 (Dropout)         (None, 1024)              0
#
#  dense_3 (Dense)             (None, 7)                 7175
#
# =================================================================
# Total params: 17,835,719
# Trainable params: 17,827,527
# Non-trainable params: 8,192
# _________________________________________________________________

# %%
early = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    min_delta=0,
    patience=3,
    verbose=0,
    mode='auto',
    baseline=None,
    restore_best_weights=True,
    start_from_epoch=0
)

# %%
model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    metrics = ['accuracy'],
)

# %%
model.fit(train_gen, epochs=50, batch_size=BATCH_SIZE, validation_data=test_gen, callbacks=[early])
# Out:
# Epoch 1/50
# 898/898 [==============================] - 89s 75ms/step - loss: 2.0143 - accuracy: 0.2252 - val_loss: 2.0681 - val_accuracy: 0.2494
# Epoch 2/50
# 898/898 [==============================] - 66s 74ms/step - loss: 1.7590 - accuracy: 0.2834 - val_loss: 1.7151 - val_accuracy: 0.3268
# Epoch 3/50
# 898/898 [==============================] - 78s 87ms/step - loss: 1.6718 - accuracy: 0.3392 - val_loss: 1.5736 - val_accuracy: 0.3803
# Epoch 4/50
# 898/898 [==============================] - 68s 76ms/step - loss: 1.5966 - accuracy: 0.3776 - val_loss: 1.5001 - val_accuracy: 0.4125
# Epoch 5/50
# 898/898 [==============================] - 69s 77ms/step - loss: 1.5142 - accuracy: 0.4116 - val_loss: 1.4834 - val_accuracy: 0.4312
# Epoch 6/50
# 898/898 [==============================] - 69s 77ms/step - loss: 1.4301 - accuracy: 0.4486 - val_loss: 1.4077 - val_accuracy: 0.4617
# Epoch 7/50
# 898/898 [==============================] - 69s 77ms/step - loss: 1.3606 - accuracy: 0.4796 - val_loss: 1.2972 - val_accuracy: 0.5032
# Epoch 8/50
# 898/898 [==============================] - 71s 78ms/step - loss: 1.2948 - accuracy: 0.5096 - val_loss: 1.2723 - val_accuracy: 0.5203
# Epoch 9/50
# 898/898 [==============================] - 68s 76ms/step - loss: 1.2486 - accuracy: 0.5293 - val_loss: 1.1868 - val_accuracy: 0.5472
# Epoch 10/50
# 898/898 [==============================] - 67s 75ms/step - loss: 1.1950 - accuracy: 0.5508 - val_loss: 1.1849 - val_accuracy: 0.5486
# Epoch 11/50
# 898/898 [==============================] - 68s 76ms/step - loss: 1.1576 - accuracy: 0.5689 - val_loss: 1.1333 - val_accuracy: 0.5724
# Epoch 12/50
# 898/898 [==============================] - 68s 76ms/step - loss: 1.1159 - accuracy: 0.5814 - val_loss: 1.2098 - val_accuracy: 0.5580
# Epoch 13/50
# 898/898 [==============================] - 69s 76ms/step - loss: 1.0858 - accuracy: 0.5962 - val_loss: 1.0702 - val_accuracy: 0.6009
# Epoch 14/50
# 898/898 [==============================] - 68s 76ms/step - loss: 1.0448 - accuracy: 0.6090 - val_loss: 1.1201 - val_accuracy: 0.5900
# Epoch 15/50
# 898/898 [==============================] - 69s 76ms/step - loss: 1.0144 - accuracy: 0.6212 - val_loss: 1.1124 - val_accuracy: 0.6027
# Epoch 16/50
# 898/898 [==============================] - 69s 77ms/step - loss: 0.9781 - accuracy: 0.6362 - val_loss: 1.0719 - val_accuracy: 0.6066

# %%
batch = test_gen.next()

plt.figure(figsize=(14, 10))
batch_pred = model.predict(batch[0])
batch_pred = list(np.argmax(batch_pred, axis=1))

for i in range(9):
  plt.subplot(3, 3, i+1)

  plt.imshow(batch[0][i])
  plt.title("Actual Value: "+class_names[int(batch[1][i])]+"\n"+class_names[batch_pred[i]])
  plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 284ms/step

# %%
base_model = tf.keras.applications.VGG16(
    input_shape=(48, 48, 3),
    include_top=False,
    weights='imagenet'
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 3s 0us/step

# %%
base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 48, 48, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 48, 48, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 48, 48, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 24, 24, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 24, 24, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 24, 24, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 12, 12, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 12, 12, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 12, 12, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 12, 12, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 6, 6, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 6, 6, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 3, 3, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 3, 3, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 3, 3, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 3, 3, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 1, 1, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
def my_new_model():
  img_inputs = tf.keras.Input(shape=(48, 48, 3))

  # base model
  x = base_model(img_inputs, training=False)
  x = tf.keras.layers.GlobalAveragePooling2D()(x)

  # Dense layers
  x = tf.keras.layers.Dense(1024, activation="relu", kernel_regularizer=tf.keras.regularizers.l1_l2(0.0001))(x)
  x = tf.keras.layers.Dropout(0.4)(x)

  x = tf.keras.layers.Dense(512, activation="relu", kernel_regularizer=tf.keras.regularizers.l1_l2(0.0001))(x)
  x = tf.keras.layers.Dropout(0.4)(x)

  output = tf.keras.layers.Dense(7, activation='softmax')(x)

  model = tf.keras.Model(inputs=img_inputs, outputs=output, name='Face_Emotion_Model_With_VGG')

  return model

# %%
model1 = my_new_model()
model1.summary()
# Out:
# Model: "Face_Emotion_Model_With_VGG"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 48, 48, 3)]       0
#
#  vgg16 (Functional)          (None, 1, 1, 512)         14714688
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              525312
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 15,768,391
# Trainable params: 15,768,391
# Non-trainable params: 0
# _________________________________________________________________

# %%
model1.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    metrics = ['accuracy'],
)

# %%
history = model1.fit(train_gen, epochs=50, batch_size=BATCH_SIZE, validation_data=test_gen, callbacks=[early])
# Out:
# Epoch 1/50
# 898/898 [==============================] - 85s 71ms/step - loss: 6.9950 - accuracy: 0.3795 - val_loss: 2.5954 - val_accuracy: 0.5056
# Epoch 2/50
# 898/898 [==============================] - 57s 64ms/step - loss: 1.9956 - accuracy: 0.5200 - val_loss: 1.6322 - val_accuracy: 0.5319
# Epoch 3/50
# 898/898 [==============================] - 58s 64ms/step - loss: 1.4423 - accuracy: 0.5670 - val_loss: 1.3208 - val_accuracy: 0.5666
# Epoch 4/50
# 898/898 [==============================] - 57s 64ms/step - loss: 1.2395 - accuracy: 0.5987 - val_loss: 1.2048 - val_accuracy: 0.5910
# Epoch 5/50
# 898/898 [==============================] - 59s 66ms/step - loss: 1.1320 - accuracy: 0.6221 - val_loss: 1.1396 - val_accuracy: 0.6084
# Epoch 6/50
# 898/898 [==============================] - 57s 63ms/step - loss: 1.0629 - accuracy: 0.6387 - val_loss: 1.1131 - val_accuracy: 0.6080
# Epoch 7/50
# 898/898 [==============================] - 57s 63ms/step - loss: 1.0037 - accuracy: 0.6601 - val_loss: 1.0825 - val_accuracy: 0.6219
# Epoch 8/50
# 898/898 [==============================] - 57s 63ms/step - loss: 0.9630 - accuracy: 0.6721 - val_loss: 1.0809 - val_accuracy: 0.6219
# Epoch 9/50
# 898/898 [==============================] - 57s 64ms/step - loss: 0.9178 - accuracy: 0.6907 - val_loss: 1.0549 - val_accuracy: 0.6310
# Epoch 10/50
# 898/898 [==============================] - 57s 63ms/step - loss: 0.8745 - accuracy: 0.7029 - val_loss: 1.0395 - val_accuracy: 0.6367
# Epoch 11/50
# 898/898 [==============================] - 58s 65ms/step - loss: 0.8277 - accuracy: 0.7223 - val_loss: 1.0399 - val_accuracy: 0.6466
# Epoch 12/50
# 898/898 [==============================] - 59s 65ms/step - loss: 0.7864 - accuracy: 0.7416 - val_loss: 1.0960 - val_accuracy: 0.6382
# Epoch 13/50
# 898/898 [==============================] - 56s 63ms/step - loss: 0.7487 - accuracy: 0.7544 - val_loss: 1.0778 - val_accuracy: 0.6482

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
batch = test_gen.next()

plt.figure(figsize=(14, 10))
batch_pred = model1.predict(batch[0])
batch_pred = list(np.argmax(batch_pred, axis=1))

for i in range(9):
  plt.subplot(3, 3, i+1)

  plt.imshow(batch[0][i])
  plt.title("Actual Value: "+class_names[int(batch[1][i])]+"\n"+class_names[batch_pred[i]])
  plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 177ms/step

# %%
model1.save('/content/mydrive/MyDrive/My Files/Datasets/Facial_Emotion/model_1')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.

# %%
def my_model_lstm():
  img_inputs = tf.keras.Input(shape=(48, 48, 3))

  # CNN Layers
  x = tf.keras.layers.Conv2D(64, 5, activation='relu', padding='same')(img_inputs)
  x = tf.keras.layers.Conv2D(64, 5, activation='relu', padding='same')(x)
  x = tf.keras.layers.MaxPooling2D(2)(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Dropout(0.3)(x)

  x = tf.keras.layers.Conv2D(128, 3, activation='relu', padding='same')(x)
  x = tf.keras.layers.Conv2D(128, 3, activation='relu', padding='same')(x)
  x = tf.keras.layers.MaxPooling2D(2)(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Dropout(0.3)(x)

  x = tf.keras.layers.Conv2D(256, 3, activation='relu', padding='same')(x)
  x = tf.keras.layers.Conv2D(256, 3, activation='relu', padding='same')(x)
  x = tf.keras.layers.MaxPooling2D(2)(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Dropout(0.3)(x)

  x = tf.keras.layers.Conv2D(512, 3, activation='relu', padding='same')(x)
  x = tf.keras.layers.Conv2D(512, 3, activation='relu', padding='same')(x)
  x = tf.keras.layers.MaxPooling2D(2)(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Dropout(0.3)(x)

  # Dense Layers
  x = tf.keras.layers.TimeDistributed(tf.keras.layers.Flatten())(x)

  x = tf.keras.layers.LSTM(128, return_sequences=True)(x)
  x = tf.keras.layers.LSTM(128)(x)

  output = tf.keras.layers.Dense(7, activation='softmax')(x)

  model = tf.keras.Model(inputs=img_inputs, outputs=output, name='Face_Emotion_Model')

  return model

# %%
new_model = my_model_lstm()
new_model.summary()
# Out:
# Model: "Face_Emotion_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 3)]       0
#
#  conv2d (Conv2D)             (None, 48, 48, 64)        4864
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 64)        102464
#
#  max_pooling2d (MaxPooling2D  (None, 24, 24, 64)       0
#  )
#
#  batch_normalization (BatchN  (None, 24, 24, 64)       256
#  ormalization)
#
#  dropout (Dropout)           (None, 24, 24, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 24, 24, 128)       73856
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 128)       147584
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 128)      0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 12, 12, 128)      512
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 12, 12, 128)       0
#
#  conv2d_4 (Conv2D)           (None, 12, 12, 256)       295168
#
#  conv2d_5 (Conv2D)           (None, 12, 12, 256)       590080
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 256)        0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 6, 6, 256)        1024
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 6, 6, 256)         0
#
#  conv2d_6 (Conv2D)           (None, 6, 6, 512)         1180160
#
#  conv2d_7 (Conv2D)           (None, 6, 6, 512)         2359808
#
#  max_pooling2d_3 (MaxPooling  (None, 3, 3, 512)        0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 3, 3, 512)        2048
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 3, 3, 512)         0
#
#  time_distributed (TimeDistr  (None, 3, 1536)          0
#  ibuted)
#
#  lstm (LSTM)                 (None, 3, 128)            852480
#
#  lstm_1 (LSTM)               (None, 128)               131584
#
#  dense (Dense)               (None, 7)                 903
#
# =================================================================
# Total params: 5,742,791
# Trainable params: 5,740,871
# Non-trainable params: 1,920
# _________________________________________________________________

# %%
new_model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    metrics = ['accuracy'],
)

# %%
history = new_model.fit(train_gen, epochs=2, batch_size=BATCH_SIZE, validation_data=test_gen, callbacks=[early])
# Out:
# Epoch 1/2
# 898/898 [==============================] - 56s 62ms/step - loss: 0.8213 - accuracy: 0.6932 - val_loss: 1.0253 - val_accuracy: 0.6335
# Epoch 2/2
# 898/898 [==============================] - 59s 65ms/step - loss: 0.8181 - accuracy: 0.6950 - val_loss: 1.0172 - val_accuracy: 0.6365

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
batch = test_gen.next()

plt.figure(figsize=(14, 10))
batch_pred = new_model.predict(batch[0])
batch_pred = list(np.argmax(batch_pred, axis=1))

for i in range(9):
  plt.subplot(3, 3, i+1)

  plt.imshow(batch[0][i])
  plt.title("Actual Value: "+class_names[int(batch[1][i])]+"\n"+class_names[batch_pred[i]])
  plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 20ms/step

# %%
new_model.save('/content/mydrive/MyDrive/My Files/Datasets/Facial Emotion/lstm_1_emotion')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 12). These functions will not be directly callable after loading.

# %%
new_model.save_weights('/content/mydrive/MyDrive/My Files/Datasets/Facial Emotion/lstm_1_emotion_wts.h5')
